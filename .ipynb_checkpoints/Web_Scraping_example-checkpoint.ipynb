# %%
#Extract the Top 25 teams in college basketball from ESPN using web scraping

# %%
from pprint import pprint
from urllib import request
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pymysql

# %%
mysql_schema = 'Project_A'
mysql_table = 'college_bball_rankings'
file = open('/Users/dhong/Desktop/csv_files/pwd.txt','r')
pwd = file.read()
ifexists_method = 'append'

#Connect to MySQL database and insert dataframe into table
db = pymysql.connect("localhost", "root", pwd, mysql_schema)

# %%
#Get latest week and add 1
cur = db.cursor()
cur.execute('select max(week) + 1 from project_a.college_bball_rankings')

    
week_variable = [row[0] for row in cur.fetchall()]

choose_wk = str(week_variable[0])

# %%
#Get top 25 teams for 2017 by Week
college_hoops_ranking = "http://www.espn.com/mens-college-basketball/rankings/_/year/2017/week/"+choose_wk+"/seasontype/2"

test_url = request.urlopen(college_hoops_ranking)

read_html = test_url.read()

# %%
soup = BeautifulSoup(read_html)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head>
#   <script src="http://cdn.espn.com/sports/optimizely.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="http://a.espncdn.com/favicon.ico" mask="" rel="icon" sizes="any"/>
#   <meta content="#CC0000" name="theme-color"/>
#   <script type="text/javascript">
#    if(true && navigator && navigator.userAgent.toLowerCase().indexOf("teamstream") >= 0) {
#         window.location = 'http://m.espn.com/mobilecache/general/apps/sc';
#     }
#   </script>
#   <title>
#    NCAA College Basketball Polls, College Basketball Rankings, NCAA Basketball Polls - ESPN
#   </title>
#   <meta content="xuj1ODRluWa0frM-BjIr_aSHoUC7HB5C1MgmYAM_GkA" name="google-site-verification"/>
#   <meta content="B1FEB7C682C46C8FCDA3130F3D18AC28" name="msvalidate.01"/>
#   <meta content="noodp" name="googlebot"/>
#   <meta content="index, follow" name="robots"/>
# ...

# %%
getdata = soup.html.find_all("div", class_="mod-content")

type(getdata)
# Out:
# bs4.element.ResultSet

# %%
getdata
# Out:
# [<div class="mod-content"><h1 class="h2">2017 NCAA Men's Basketball Rankings -  Week 12 (Jan. 23)</h1><div style="position: absolute; right: 130px; top: 50px;">
#  <!-- gpt ad type: presentedbylogo -->
#  <div class="ad-slot ad-slot-presentedbylogo" data-slot-kvps="pos=presentedbylogo" data-slot-type="presentedbylogo"></div></div><div id="dropdowns"><span class="year">Year:</span><form class="js-goto" style="display: inline;"><select class="tablesm"><option selected="selected" value="http://www.espn.com/mens-college-basketball/rankings/_/week/12/seasontype/2">2016-17</option>
#  <option value="http://www.espn.com/mens-college-basketball/rankings/_/year/2016/week/12/seasontype/2">2015-16</option>
#  <option value="http://www.espn.com/mens-college-basketball/rankings/_/year/2015/week/12/seasontype/2">2014-15</option>
#  <option value="http://www.espn.com/mens-college-basketball/rankings/_/year/2014/week/12/seasontype/2">2013-14</option>
# ...

# %%
rankings = getdata[1]

# %%
rankings
# Out:
# <div class="mod-content"><table cellpadding="3" cellspacing="1" class="tablehead"><tr class="stathead"><td colspan="4">AP Top 25</td></tr><tr class="colhead"><td>RK</td><td>TEAM</td><td align="center">RECORD</td><td align="center">PTS</td></tr><tr class="oddrow team-41-222"><td>1</td><td><a href="http://www.espn.com/mens-college-basketball/team/_/id/222/villanova-wildcats">Villanova</a> (35) </td><td align="center">19-1</td><td align="center">1,591</td></tr><tr class="evenrow team-41-2305"><td>2</td><td><a href="http://www.espn.com/mens-college-basketball/team/_/id/2305/kansas-jayhawks">Kansas</a> (28) </td><td align="center">18-1</td><td align="center">1,572</td></tr><tr class="oddrow team-41-2250"><td>3</td><td><a href="http://www.espn.com/mens-college-basketball/team/_/id/2250/gonzaga-bulldogs">Gonzaga</a> (2) </td><td align="center">19-0</td><td align="center">1,471</td></tr><tr class="evenrow team-41-96"><td>4</td><td><a href="http://www.espn.com/mens-college-basketball/team/_/i
# ...

# %%
rows = rankings.findChildren(['td'])
rows
# Out:
# [<td colspan="4">AP Top 25</td>,
#  <td>RK</td>,
#  <td>TEAM</td>,
#  <td align="center">RECORD</td>,
#  <td align="center">PTS</td>,
#  <td>1</td>,
#  <td><a href="http://www.espn.com/mens-college-basketball/team/_/id/222/villanova-wildcats">Villanova</a> (35) </td>,
#  <td align="center">19-1</td>,
#  <td align="center">1,591</td>,
#  <td>2</td>,
#  <td><a href="http://www.espn.com/mens-college-basketball/team/_/id/2305/kansas-jayhawks">Kansas</a> (28) </td>,
#  <td align="center">18-1</td>,
#  <td align="center">1,572</td>,
#  <td>3</td>,
#  <td><a href="http://www.espn.com/mens-college-basketball/team/_/id/2250/gonzaga-bulldogs">Gonzaga</a> (2) </td>,
#  <td align="center">19-0</td>,
#  <td align="center">1,471</td>,
#  <td>4</td>,
#  <td><a href="http://www.espn.com/mens-college-basketball/team/_/id/96/kentucky-wildcats">Kentucky</a></td>,
#  <td align="center">17-2</td>,
#  <td align="center">1,414</td>,
#  <td>5</td>,
# ...

# %%
x = 0
end = len(rows)

results = []

while x < end:
    for y in rows[x]:
        if y.string == None:
            for link in rankings.find_all('a'):
                results.append(link.get('href'))
        else:
            results.append(y.string.split(' '))
            
    x = x + 1

results
# Out:
# [['AP', 'Top', '25'],
#  ['RK'],
#  ['TEAM'],
#  ['RECORD'],
#  ['PTS'],
#  ['1'],
#  ['Villanova'],
#  ['', '(35)', ''],
#  ['19-1'],
#  ['1,591'],
#  ['2'],
#  ['Kansas'],
#  ['', '(28)', ''],
#  ['18-1'],
#  ['1,572'],
#  ['3'],
#  ['Gonzaga'],
#  ['', '(2)', ''],
#  ['19-0'],
#  ['1,471'],
#  ['4'],
#  ['Kentucky'],
#  ['17-2'],
#  ['1,414'],
#  ['5'],
#  ['Baylor'],
#  ['18-1'],
#  ['1,379'],
#  ['6'],
#  ['Florida', 'State'],
#  ['18-2'],
#  ['1,215'],
#  ['7'],
#  ['Arizona'],
#  ['18-2'],
#  ['1,190'],
#  ['8'],
#  ['UCLA'],
#  ['19-2'],
#  ['1,177'],
#  ['9'],
#  ['North', 'Carolina'],
#  ['18-3'],
#  ['1,171'],
#  ['10'],
#  ['Oregon'],
#  ['18-2'],
#  ['1,035'],
#  ['11'],
#  ['Butler'],
#  ['17-3'],
#  ['914'],
#  ['12'],
#  ['Virginia'],
#  ['15-3'],
#  ['803'],
#  ['13'],
#  ['Louisville'],
#  ['16-4'],
#  ['796'],
#  ['14'],
#  ['Notre', 'Dame'],
#  ['17-3'],
#  ['767'],
#  ['15'],
#  ['Wisconsin'],
#  ['16-3'],
#  ['746'],
#  ['16'],
#  ['Creighton'],
#  ['18-2'],
# ...

# %%
final = []

for x in results:
    if len(x) < 3:
        final.append(x)
        
final
# Out:
# [['RK'],
#  ['TEAM'],
#  ['RECORD'],
#  ['PTS'],
#  ['1'],
#  ['Villanova'],
#  ['19-1'],
#  ['1,591'],
#  ['2'],
#  ['Kansas'],
#  ['18-1'],
#  ['1,572'],
#  ['3'],
#  ['Gonzaga'],
#  ['19-0'],
#  ['1,471'],
#  ['4'],
#  ['Kentucky'],
#  ['17-2'],
#  ['1,414'],
#  ['5'],
#  ['Baylor'],
#  ['18-1'],
#  ['1,379'],
#  ['6'],
#  ['Florida', 'State'],
#  ['18-2'],
#  ['1,215'],
#  ['7'],
#  ['Arizona'],
#  ['18-2'],
#  ['1,190'],
#  ['8'],
#  ['UCLA'],
#  ['19-2'],
#  ['1,177'],
#  ['9'],
#  ['North', 'Carolina'],
#  ['18-3'],
#  ['1,171'],
#  ['10'],
#  ['Oregon'],
#  ['18-2'],
#  ['1,035'],
#  ['11'],
#  ['Butler'],
#  ['17-3'],
#  ['914'],
#  ['12'],
#  ['Virginia'],
#  ['15-3'],
#  ['803'],
#  ['13'],
#  ['Louisville'],
#  ['16-4'],
#  ['796'],
#  ['14'],
#  ['Notre', 'Dame'],
#  ['17-3'],
#  ['767'],
#  ['15'],
#  ['Wisconsin'],
#  ['16-3'],
#  ['746'],
#  ['16'],
#  ['Creighton'],
#  ['18-2'],
#  ['731'],
#  ['17'],
#  ['Duke'],
#  ['15-4'],
#  ['628'],
#  ['18'],
# ...

# %%
data = []

a = 4
b = a + 4
end = len(final)

for x in final:
    while a < end:
        data.append(final[a:b])
        
        a = a + 4
        b = a + 4

data
# Out:
# [[['1'], ['Villanova'], ['19-1'], ['1,591']],
#  [['2'], ['Kansas'], ['18-1'], ['1,572']],
#  [['3'], ['Gonzaga'], ['19-0'], ['1,471']],
#  [['4'], ['Kentucky'], ['17-2'], ['1,414']],
#  [['5'], ['Baylor'], ['18-1'], ['1,379']],
#  [['6'], ['Florida', 'State'], ['18-2'], ['1,215']],
#  [['7'], ['Arizona'], ['18-2'], ['1,190']],
#  [['8'], ['UCLA'], ['19-2'], ['1,177']],
#  [['9'], ['North', 'Carolina'], ['18-3'], ['1,171']],
#  [['10'], ['Oregon'], ['18-2'], ['1,035']],
#  [['11'], ['Butler'], ['17-3'], ['914']],
#  [['12'], ['Virginia'], ['15-3'], ['803']],
#  [['13'], ['Louisville'], ['16-4'], ['796']],
#  [['14'], ['Notre', 'Dame'], ['17-3'], ['767']],
#  [['15'], ['Wisconsin'], ['16-3'], ['746']],
#  [['16'], ['Creighton'], ['18-2'], ['731']],
#  [['17'], ['Duke'], ['15-4'], ['628']],
#  [['18'], ['West', 'Virginia'], ['15-4'], ['569']],
#  [['19'], ['Cincinnati'], ['17-2'], ['478']],
#  [['20'], ['Purdue'], ['16-4'], ['412']],
# ...

# %%
df = pd.DataFrame({
        'RK':[x[0] for x in data],
        'TEAM':[x[1] for x in data],
        'RECORD':[x[2] for x in data],
        'PTS':[x[3] for x in data],
        'WEEK': choose_wk
    })

df
# Out:
#         PTS  RECORD    RK               TEAM WEEK
# 0   [1,591]  [19-1]   [1]        [Villanova]   12
# 1   [1,572]  [18-1]   [2]           [Kansas]   12
# 2   [1,471]  [19-0]   [3]          [Gonzaga]   12
# 3   [1,414]  [17-2]   [4]         [Kentucky]   12
# 4   [1,379]  [18-1]   [5]           [Baylor]   12
# 5   [1,215]  [18-2]   [6]   [Florida, State]   12
# 6   [1,190]  [18-2]   [7]          [Arizona]   12
# 7   [1,177]  [19-2]   [8]             [UCLA]   12
# 8   [1,171]  [18-3]   [9]  [North, Carolina]   12
# 9   [1,035]  [18-2]  [10]           [Oregon]   12
# 10    [914]  [17-3]  [11]           [Butler]   12
# 11    [803]  [15-3]  [12]         [Virginia]   12
# 12    [796]  [16-4]  [13]       [Louisville]   12
# 13    [767]  [17-3]  [14]      [Notre, Dame]   12
# 14    [746]  [16-3]  [15]        [Wisconsin]   12
# 15    [731]  [18-2]  [16]        [Creighton]   12
# 16    [628]  [15-4]  [17]             [Duke]   12
# 17    [569]  [15-4]  [18]   [West, Virginia]   12
# ...

# %%
#Remove brackets from data values
df['TEAM'] = df['TEAM'].str[0] + ' ' +df['TEAM'].str[1].fillna('') 
df['RK'] = df['RK'].str[0]
df['RECORD'] = df['RECORD'].str[0]
df['PTS'] = df['PTS'].str[0]

#Remove comma from PTS column to ensure it can become an intger
df['PTS'] = df['PTS'].str.replace(',','')

#Convert string to int for PTS column
df['PTS'] = df['PTS'].astype(int)

df
# Out:
#      PTS RECORD  RK            TEAM WEEK
# 0   1591   19-1   1      Villanova    12
# 1   1572   18-1   2         Kansas    12
# 2   1471   19-0   3        Gonzaga    12
# 3   1414   17-2   4       Kentucky    12
# 4   1379   18-1   5         Baylor    12
# 5   1215   18-2   6   Florida State   12
# 6   1190   18-2   7        Arizona    12
# 7   1177   19-2   8           UCLA    12
# 8   1171   18-3   9  North Carolina   12
# 9   1035   18-2  10         Oregon    12
# 10   914   17-3  11         Butler    12
# 11   803   15-3  12       Virginia    12
# 12   796   16-4  13     Louisville    12
# 13   767   17-3  14      Notre Dame   12
# 14   746   16-3  15      Wisconsin    12
# 15   731   18-2  16      Creighton    12
# 16   628   15-4  17           Duke    12
# 17   569   15-4  18   West Virginia   12
# 18   478   17-2  19     Cincinnati    12
# 19   412   16-4  20         Purdue    12
# 20   290   17-2  21    Saint Mary's   12
# 21   261   17-2  22       Maryland    12
# ...

# %%
df.to_sql(con=db, name=mysql_table, index=False, if_exists=ifexists_method, flavor='mysql')
# Out:
# /Users/dhong/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py:1165: FutureWarning: The 'mysql' flavor with DBAPI connection is deprecated and will be removed in future versions. MySQL will be further supported with SQLAlchemy connectables.
#   chunksize=chunksize, dtype=dtype)

# %%
#Query from MySQL to see the results
cur = db.cursor()
cur.execute("select * from project_a.college_bball_rankings where week = "+choose_wk+"")

for row in cur:
    print(row)
# Out:
# (1, 'Villanova ', '19-1', 1591, 12)
# (2, 'Kansas ', '18-1', 1572, 12)
# (3, 'Gonzaga ', '19-0', 1471, 12)
# (4, 'Kentucky ', '17-2', 1414, 12)
# (5, 'Baylor ', '18-1', 1379, 12)
# (6, 'Florida State', '18-2', 1215, 12)
# (7, 'Arizona ', '18-2', 1190, 12)
# (8, 'UCLA ', '19-2', 1177, 12)
# (9, 'North Carolina', '18-3', 1171, 12)
# (10, 'Oregon ', '18-2', 1035, 12)
# (11, 'Butler ', '17-3', 914, 12)
# (12, 'Virginia ', '15-3', 803, 12)
# (13, 'Louisville ', '16-4', 796, 12)
# (14, 'Notre Dame', '17-3', 767, 12)
# (15, 'Wisconsin ', '16-3', 746, 12)
# (16, 'Creighton ', '18-2', 731, 12)
# (17, 'Duke ', '15-4', 628, 12)
# (18, 'West Virginia', '15-4', 569, 12)
# (19, 'Cincinnati ', '17-2', 478, 12)
# (20, 'Purdue ', '16-4', 412, 12)
# (21, "Saint Mary's", '17-2', 290, 12)
# (22, 'Maryland ', '17-2', 261, 12)
# (23, 'South Carolina', '15-4', 171, 12)
# (24, 'Xavier ', '14-5', 146, 12)
# (25, 'Florida ', '14-5', 47, 12)
